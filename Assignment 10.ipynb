# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## ***1.Display Top 10 Rows of The Dataset***

# %%
df = pd.read_csv("adult.csv")
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                  ?      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                  ?      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %% [markdown]
# ## ***2. Check Last 10 Rows of The Dataset***

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# 48835  Married-civ-spouse    Exec-managerial        Husband
# 48836       Never-married    Protective-serv  Not-in-family
# 48837  Married-civ-spouse       Tech-support           Wife
# 48838  Married-civ-spouse  Machine-op-inspct        Husband
# 48839             Widowed       Adm-clerical      Unmarried
# 48840       Never-married       Adm-clerical      Own-child
# 48841  Married-civ-spouse    Exec-managerial           Wife
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 48832  Amer-Indian-Eskimo    Male             0             0              40
# 48833               White    Male             0             0              45
# 48834  Asian-Pac-Islander    Male             0             0              11
# 48835               White    Male             0             0              40
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              38
# 48838               White    Male             0             0              40
# 48839               White  Female             0             0              40
# 48840               White    Male             0             0              20
# 48841               White  Female         15024             0              40
#
#       native-country income
# 48832  United-States  <=50K
# 48833  United-States  <=50K
# 48834         Taiwan  <=50K
# 48835  United-States   >50K
# 48836  United-States  <=50K
# 48837  United-States  <=50K
# 48838  United-States   >50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K

# %% [markdown]
# ## ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# ## ***4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
#number of rows and columns
rows = df.shape[0]
columns = df.shape[1]
print(f"Rows are {rows}")
print(f"Columns are {columns}")
# Out:
# Rows are 48842
# Columns are 15

# %%
#datatypes of each columns
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
#memory requirement for each column
df.memory_usage(deep=True)
# Out:
# Index                  132
# age                 390736
# workclass          2777687
# fnlwgt              390736
# education          2804609
# educational-num     390736
# marital-status     3096878
# occupation         2988495
# relationship       2839611
# race               2663325
# gender             2621010
# capital-gain        390736
# capital-loss        390736
# hours-per-week      390736
# native-country     2994349
# income             2625781
# dtype: int64

# %% [markdown]
# ## ***5.Check Null Values And Also Create A Heatmap In The Dataset***

# %%
null_values = df.isnull().sum()
null_values
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
plt.title("Visualizing Null Values: A Heatmap Analysis")
plt.show()

# %% [markdown]
# ## ***6. Fetch Random Sample From the Dataset (50%)***

# %%
df_percent = df.sample(frac=0.5)
df_percent
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 4255    45  Self-emp-not-inc  180680          11th                7
# 20640   22           Private  195532     Bachelors               13
# 47026   22           Private  133833  Some-college               10
# 39785   31         Local-gov  153005     Bachelors               13
# 13471   23           Private   39551    Assoc-acdm               12
# ...    ...               ...     ...           ...              ...
# 31928   40           Private  124520     Assoc-voc               11
# 40777   32           Private  113838  Some-college               10
# 22462   50           Private  178530   Prof-school               15
# 44880   31           Private  176969     Bachelors               13
# 5584    22           Private  144238          11th                7
#
#            marital-status         occupation   relationship   race  gender  \
# 4255   Married-civ-spouse       Craft-repair        Husband  White    Male
# 20640       Never-married     Prof-specialty  Not-in-family  White  Female
# 47026       Never-married      Other-service      Own-child  White  Female
# 39785  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 13471       Never-married              Sales      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 31928            Divorced       Craft-repair      Unmarried  White    Male
# 40777  Married-civ-spouse  Handlers-cleaners        Husband  White    Male
# 22462  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 44880       Never-married    Exec-managerial  Not-in-family  White    Male
# 5584        Never-married    Farming-fishing      Own-child  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 4255              0             0              35  United-States  <=50K
# 20640          8614             0              40  United-States   >50K
# 47026             0             0              25  United-States  <=50K
# 39785             0             0              40  United-States   >50K
# 13471             0             0              12  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 31928             0             0              50  United-States   >50K
# 40777             0             0              40  United-States  <=50K
# 22462             0             0              60  United-States   >50K
# 44880             0             0              55  United-States  <=50K
# 5584              0             0              38  United-States  <=50K
#
# [24421 rows x 15 columns]

# %%
df_elements = df.sample(n=7)
df_elements
# Out:
#        age    workclass  fnlwgt     education  educational-num  \
# 42787   76      Private  208843       7th-8th                4
# 33235   42    Local-gov   99554  Some-college               10
# 8719    32    State-gov   59083       HS-grad                9
# 24261   34  Federal-gov   67083     Bachelors               13
# 34977   55      Private  101338          10th                6
# 44598   38      Private  283293       HS-grad                9
# 36752   40      Private  442045  Some-college               10
#
#            marital-status        occupation   relationship  \
# 42787             Widowed   Protective-serv  Not-in-family
# 33235  Married-civ-spouse  Transport-moving        Husband
# 8719   Married-civ-spouse   Exec-managerial        Husband
# 24261       Never-married   Exec-managerial      Unmarried
# 34977  Married-civ-spouse      Craft-repair        Husband
# 44598  Married-civ-spouse      Craft-repair        Husband
# 36752  Married-civ-spouse    Prof-specialty        Husband
#
#                      race gender  capital-gain  capital-loss  hours-per-week  \
# 42787               White   Male             0             0              30
# 33235               White   Male             0             0              40
# 8719                White   Male             0             0              60
# 24261  Asian-Pac-Islander   Male          1471             0              40
# 34977               White   Male             0             0              40
# 44598               Black   Male             0             0              40
# 36752               White   Male             0             0              40
#
#       native-country income
# 42787  United-States  <=50K
# 33235  United-States  <=50K
# 8719   United-States   >50K
# 24261       Cambodia  <=50K
# 34977  United-States  <=50K
# 44598  United-States  <=50K
# 36752  United-States   >50K

# %% [markdown]
# ## ***7. Perform Data Cleaning [Replace'?' with NaN]***

# %%
df = df.replace("?",np.nan)
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18               NaN  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29               NaN  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                NaN      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                NaN      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %% [markdown]
# ## ***8. Drop All The Missing Values***

# %%
drop_null_values = df.dropna()
drop_null_values
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45222 rows x 15 columns]

# %% [markdown]
# ## ***9. Check Duplicate Data and Drop Them***

# %%
duplicate = df.duplicated().sum()
print(f"Number of duplicate rows are {duplicate}")
# Out:
# Number of duplicate rows are 52

# %%
drop_duplicate = df.drop_duplicates() 
print(f"Shape of DataFrame after removing duplicates:{drop_duplicate.shape} ")
# Out:
# Shape of DataFrame after removing duplicates:(48790, 15)

# %%
rows1 ,column1 = drop_duplicate.shape
print(f"Rows are {rows1}")
print(f"Columns are {column1}")
# Out:
# Rows are 48790
# Columns are 15

# %% [markdown]
# ## ***10. Get Overall Statistics About The Dataframe***

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# ## ***11. Drop The Columns education-num, capital-gain and capital-loss***

# %%
df = df.drop('educational-num',axis=1)
df = df.drop('capital-gain',axis=1)
df = df.drop('capital-loss',axis=1)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 4   18        NaN  103497  Some-college       Never-married
#
#           occupation relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct    Own-child  Black    Male              40
# 1    Farming-fishing      Husband  White    Male              50
# 2    Protective-serv      Husband  White    Male              40
# 3  Machine-op-inspct      Husband  Black    Male              40
# 4                NaN    Own-child  White  Female              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 4  United-States  <=50K

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# ## ***12. What Is The Distribution of Age Column Show In Graph?***

# %%
age_distribution = df['age'].value_counts()
age_distribution
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=age_distribution.index  , y=age_distribution.values ,palette='viridis')
plt.title('Distribution of Ages')
plt.xlabel('Ages')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## ***13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method And Also Without Using Between Method***

# %%
age_between = df[df['age'].between(17,48,inclusive='both')]
age_between
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 4       18        NaN  103497  Some-college       Never-married
# ...    ...        ...     ...           ...                 ...
# 48834   32    Private  116138       Masters       Never-married
# 48836   22    Private  310152  Some-college       Never-married
# 48837   27    Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40    Private  154374       HS-grad  Married-civ-spouse
# 48840   22    Private  201490       HS-grad       Never-married
#
#               occupation   relationship                race  gender  \
# 0      Machine-op-inspct      Own-child               Black    Male
# 1        Farming-fishing        Husband               White    Male
# 2        Protective-serv        Husband               White    Male
# 3      Machine-op-inspct        Husband               Black    Male
# 4                    NaN      Own-child               White  Female
# ...                  ...            ...                 ...     ...
# 48834       Tech-support  Not-in-family  Asian-Pac-Islander    Male
# 48836    Protective-serv  Not-in-family               White    Male
# 48837       Tech-support           Wife               White  Female
# 48838  Machine-op-inspct        Husband               White    Male
# 48840       Adm-clerical      Own-child               White    Male
#
#        hours-per-week native-country income
# 0                  40  United-States  <=50K
# 1                  50  United-States  <=50K
# 2                  40  United-States   >50K
# 3                  40  United-States   >50K
# 4                  30  United-States  <=50K
# ...               ...            ...    ...
# 48834              11         Taiwan  <=50K
# 48836              40  United-States  <=50K
# 48837              38  United-States  <=50K
# 48838              40  United-States   >50K
# 48840              20  United-States  <=50K
#
# [37321 rows x 12 columns]

# %%
total = age_between.shape[0]
print(f"Total number of persons aged between 17 and 48 (inclusive) using between method: {total}")
# Out:
# Total number of persons aged between 17 and 48 (inclusive) using between method: 37321

# %% [markdown]
# ## ***14. What is The Distribution of Workclass Column***

# %%
workclass_distribution = df['workclass'].value_counts()
workclass_distribution
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=workclass_distribution.index, y=workclass_distribution.values, palette='viridis')
plt.title('Distribution of Workclass Categories')
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## ***15. How Many Person Having Bachelors or Masters Degree***

# %%
df[df['education'] == "Bachelors"]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 11      36       Federal-gov  212465  Bachelors  Married-civ-spouse
# 20      34           Private  107914  Bachelors  Married-civ-spouse
# 23      25           Private  220931  Bachelors       Never-married
# 24      25           Private  205947  Bachelors  Married-civ-spouse
# 32      24  Self-emp-not-inc  188274  Bachelors       Never-married
# ...    ...               ...     ...        ...                 ...
# 48811   35               NaN  320084  Bachelors  Married-civ-spouse
# 48812   30               NaN   33811  Bachelors       Never-married
# 48814   54           Private  337992  Bachelors  Married-civ-spouse
# 48817   34           Private  160216  Bachelors       Never-married
# 48819   38           Private  139180  Bachelors            Divorced
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 20        Tech-support        Husband               White    Male
# 23      Prof-specialty  Not-in-family               White    Male
# 24      Prof-specialty        Husband               White    Male
# 32               Sales  Not-in-family               White    Male
# ...                ...            ...                 ...     ...
# 48811              NaN           Wife               White  Female
# 48812              NaN  Not-in-family  Asian-Pac-Islander  Female
# 48814  Exec-managerial        Husband  Asian-Pac-Islander    Male
# 48817  Exec-managerial  Not-in-family               White  Female
# 48819   Prof-specialty      Unmarried               Black  Female
#
#        hours-per-week native-country income
# 11                 40  United-States  <=50K
# 20                 47  United-States   >50K
# 23                 43           Peru  <=50K
# 24                 40  United-States  <=50K
# 32                 50  United-States  <=50K
# ...               ...            ...    ...
# 48811              55  United-States   >50K
# 48812              99  United-States  <=50K
# 48814              50          Japan   >50K
# 48817              55  United-States   >50K
# 48819              45  United-States   >50K
#
# [8025 rows x 12 columns]

# %% [markdown]
# ## ***16. Create A Boxplot Of The "Income" Column Against The "Age" Column, Segmented By Gender***

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='age' , y='income' , hue='gender' ,data = df)
plt.title("Boxplot of Income vs Age, Segmented by Gender")
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# ## ***17. Replace income value [<=50k with 0 and >50k with 1]***

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education      marital-status  \
# 0   25           Private  226802          11th       Never-married
# 1   38           Private   89814       HS-grad  Married-civ-spouse
# 2   28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44           Private  160323  Some-college  Married-civ-spouse
# 4   18               NaN  103497  Some-college       Never-married
# 5   34           Private  198693          10th       Never-married
# 6   29               NaN  227026       HS-grad       Never-married
# 7   63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8   24           Private  369667  Some-college       Never-married
# 9   55           Private  104996       7th-8th  Married-civ-spouse
#
#           occupation   relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black    Male              40
# 1    Farming-fishing        Husband  White    Male              50
# 2    Protective-serv        Husband  White    Male              40
# 3  Machine-op-inspct        Husband  Black    Male              40
# 4                NaN      Own-child  White  Female              30
# 5      Other-service  Not-in-family  White    Male              30
# 6                NaN      Unmarried  Black    Male              40
# 7     Prof-specialty        Husband  White    Male              32
# 8      Other-service      Unmarried  White  Female              40
# 9       Craft-repair        Husband  White    Male              10
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 4  United-States  <=50K
# 5  United-States  <=50K
# 6  United-States  <=50K
# 7  United-States   >50K
# 8  United-States  <=50K
# 9  United-States  <=50K

# %%
df['income'] = np.where(df['income'] == '<=50K', 0, 1)

# Check the updated DataFrame
print(df['income'].head())
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: income, dtype: int32

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 4   18        NaN  103497  Some-college       Never-married
#
#           occupation relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct    Own-child  Black    Male              40
# 1    Farming-fishing      Husband  White    Male              50
# 2    Protective-serv      Husband  White    Male              40
# 3  Machine-op-inspct      Husband  Black    Male              40
# 4                NaN    Own-child  White  Female              30
#
#   native-country  income
# 0  United-States       0
# 1  United-States       0
# 2  United-States       1
# 3  United-States       1
# 4  United-States       0

# %% [markdown]
# ## ***18. Which Workclass getting The Highest Salary***

# %%
high_salary_of_wrokclass = df.groupby('workclass')['income'].mean().idxmax()
print(f"The workclass with the highest average salary is {high_salary_of_wrokclass}")
# Out:
# The workclass with the highest average salary is Self-emp-inc

# %% [markdown]
# ## ***19. Who Has Better Chance To Get Salary >50k Male or Female***

# %%
df['income'].value_counts()
# Out:
# income
# 0    37155
# 1    11687
# Name: count, dtype: int64

# %%
high_salary_of_gender = df.groupby('gender')['income'].mean().idxmax()
print(f"The workclass with the highest average salary is {high_salary_of_gender}.")
# Out:
# The workclass with the highest average salary is Male.

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='gender',hue='income',data=df)
plt.title("Countplot of Income vs Gender")
plt.xlabel("Gender")
plt.ylabel("Income")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## ***20. Convert Workclass Column DataType To Category Datatype***

# %%
df['workclass'] = df['workclass'].astype('category')
print(df['workclass'].dtypes)
# Out:
# category
